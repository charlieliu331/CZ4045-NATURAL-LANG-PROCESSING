# %% [markdown]
# # Libraries Needed

# %%
# Basic Libraries
## make sure python version 3.8 and above
# !pip install snscrape
# OR !pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git

import snscrape.modules.twitter as sntwitter
import pandas as pd
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
import os
import matplotlib.dates as mdates
sb.set() # set the default Seaborn style for graphics
import traceback

# %% [markdown]
# ## Scraping

# %%
#All operators are evaluated in a case-insensitive manner.

def scraping_year(start, end, amount):
    tweets_df = {}
    tweets_list = []
    
    # Using TwitterSearchScraper to scrape data and append tweets to list
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('("USA" OR "the US" OR "United States of America" OR "America") (#gunlaws OR "gun control" OR "gun laws" OR "gun violence") \ 
                                                                -is:retweet lang:en since:%s until:%s' %(start,end)).get_items()):
        if i>(amount-1):
            break

        tweets_list.append([tweet.date, tweet.id, tweet.content, tweet.retweetCount, tweet.likeCount, tweet.user.username])


    # Creating a dataframe from the tweets list above
    tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'TweetId', 'Text', 'RetweetCount', 'LikeCount','Username'])


    return tweets_df

# %% [markdown]
# ## Year 2020 - 2022

# %% [markdown]
# minimum: 10,000 records and  100,000 words.
# scrape about 4,000 records for 2020, 2021, 2022

# %%
df_2020_to_2022 = scraping_year("2020-01-01", "2022-09-06", 12000)

# %%
df_2020_to_2022.to_csv('Tweets_gun_laws.csv', index = False)

# %%
df_2020_to_2022.sample(20)
# Out:
#                       Datetime              TweetId  \
# 2457 2020-12-01 17:44:04+00:00  1333829231688769537
# 3939 2020-11-13 05:28:20+00:00  1327121094474686466
# 28   2020-12-31 12:16:12+00:00  1344618354607337473
# 246  2020-12-28 11:06:41+00:00  1343513697260593152
# 3869 2020-11-14 05:27:42+00:00  1327483322478571521
# 2353 2020-12-03 01:36:38+00:00  1334310541473419264
# 533  2020-12-23 07:09:44+00:00  1341642128884154368
# 3613 2020-11-17 21:09:22+00:00  1328807464620478465
# 3950 2020-11-13 01:49:52+00:00  1327066116347228160
# 1313 2020-12-14 19:26:27+00:00  1338566036510011392
# 2524 2020-11-30 20:06:24+00:00  1333502659811282945
# 2747 2020-11-28 07:30:01+00:00  1332587535772438529
# 3955 2020-11-13 01:24:08+00:00  1327059639905599489
# 54   2020-12-30 23:01:13+00:00  1344418293516546049
# 600  2020-12-22 15:09:12+00:00  1341400403137671172
# 3333 2020-11-21 08:30:01+00:00  1330065922011373568
# 976  2020-12-17 06:38:38+00:00  1339459974330609664
# ...
